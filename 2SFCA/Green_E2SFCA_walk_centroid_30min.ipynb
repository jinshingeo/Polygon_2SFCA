# %%
import geopandas as gpd
import pandas as pd
import osmnx as ox
import time
import numpy as np
from tqdm import tqdm, trange
from shapely.geometry import Point, MultiPoint
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
from scipy.stats import pearsonr
from matplotlib_scalebar.scalebar import ScaleBar

import utils
import warnings
warnings.filterwarnings("ignore")

# %%
import os
print(os.getcwd())  # 현재 작업 디렉터리 출력
# Out:
# /Users/jin/Downloads/2SFCA

# %%
parks = gpd.read_file('./data/도시숲전체_면_서울_최종_중분류.shp') # nas greenspace.shp

# %%
pop = pd.read_csv('./data/LOCAL_PEOPLE_20250509.csv', encoding='cp949')
pop
# Out:
#         ?"기준일ID"  시간대구분     행정동코드          집계구코드    총생활인구수 남자0세부터9세생활인구수  \
# 0       20250509      0  11110515  1101072010001  586.4714       29.5831
# 1       20250509      0  11110515  1101072010002  646.7441        8.6714
# 2       20250509      0  11110515  1101072010003  544.3822       32.1705
# 3       20250509      0  11110515  1101072010004   22.1353             *
# 4       20250509      0  11110515  1101072010005  230.0979       13.3169
# ...          ...    ...       ...            ...       ...           ...
# 459022  20250509     23  11740700  1125071022201  835.9834        33.851
# 459023  20250509     23  11740700  1125071022202  208.8763        7.2179
# 459024  20250509     23  11740700  1125071022501  862.2973       55.1454
# 459025  20250509     23  11740700  1125071022701   14.8689             *
# 459026  20250509     23  11740700  1125071023701  585.9690       20.3088
#
#        남자10세부터14세생활인구수 남자15세부터19세생활인구수 남자20세부터24세생활인구수 남자25세부터29세생활인구수  ...  \
# 0              18.8504         28.6376         10.7038          15.015  ...
# 1               5.5254          7.4187          9.9569         25.9362  ...
# 2              20.4991         25.2295         26.3854         10.4211  ...
# 3                    *               *               *               *  ...
# 4               8.4855         10.6206         10.3971           4.505  ...
# ...                ...             ...             ...             ...  ...
# 459022         17.0763         22.5008         11.8425         32.1117  ...
# 459023               *          6.1149               *          8.4251  ...
# 459024         27.8183         20.0382         17.6224          6.5735  ...
# 459025               *               *               *               *  ...
# 459026         10.2449         17.1526          9.0497         23.6016  ...
#
#        여자25세부터29세생활인구수 여자30세부터34세생활인구수 여자35세부터39세생활인구수 여자40세부터44세생활인구수  \
# 0              16.9262         19.1877         18.8278         25.0539
# 1              24.6645         26.9655         42.1877         30.1979
# 2               6.7781         10.7571         30.6213         16.4315
# 3                    *               *               *               *
# 4                    *          4.7695         13.9347          7.1354
# ...                ...             ...             ...             ...
# 459022         33.4731         27.4596         28.2361         32.1044
# 459023          8.6028          6.9541          7.0286          7.7531
# 459024         29.1631         48.0979         45.5848         39.7751
# 459025               *               *               *               *
# 459026         24.0915         19.4984         19.6762         21.7478
#
#        여자45세부터49세생활인구수 여자50세부터54세생활인구수 여자55세부터59세생활인구수 여자60세부터64세생활인구수  \
# 0              30.7039         24.2207         23.4848         26.0297
# 1              45.7185         33.7703         26.3983         21.3674
# 2              40.6366         26.8248         18.7789          15.414
# 3                    *               *               *               *
# 4              16.5488          10.889          7.9717          6.7941
# ...                ...             ...             ...             ...
# 459022         53.6668         33.1693         33.3918         32.6982
# 459023         13.7632          8.3283          8.2746          8.2923
# 459024         49.5781         25.4719         26.0188         32.8898
# 459025               *               *               *               *
# 459026         38.5418         23.3573         23.2146         23.2538
#
#        여자65세부터69세생활인구수 여자70세이상생활인구수
# 0               9.8527      30.6477
# 1              19.7889      58.8045
# 2              12.7254      42.2127
# 3                    *            *
# 4               5.1862      17.0416
# ...                ...          ...
# 459022         25.8544      77.9975
# 459023          6.6347      20.5611
# 459024         15.2907      61.6968
# 459025               *            *
# 459026         18.5928      57.6298
#
# [459027 rows x 33 columns]

# %%
pop= pop[['시간대구분','집계구코드','총생활인구수']]

# %%
pop
# Out:
#         시간대구분          집계구코드    총생활인구수
# 0           0  1101072010001  586.4714
# 1           0  1101072010002  646.7441
# 2           0  1101072010003  544.3822
# 3           0  1101072010004   22.1353
# 4           0  1101072010005  230.0979
# ...       ...            ...       ...
# 459022     23  1125071022201  835.9834
# 459023     23  1125071022202  208.8763
# 459024     23  1125071022501  862.2973
# 459025     23  1125071022701   14.8689
# 459026     23  1125071023701  585.9690
#
# [459027 rows x 3 columns]

# %%
pop['집계구코드']=pop['집계구코드'].astype(str).str[:7]

# %%
new_pop = pop[(pop['시간대구분'] >= 1) & (pop['시간대구분'] <= 4)]

# %%
new_pop.info
# Out:
# <bound method DataFrame.info of        시간대구분    집계구코드    총생활인구수
# 19095      1  1101072  580.8824
# 19096      1  1101072  637.2533
# 19097      1  1101072  549.2267
# 19098      1  1101072   22.8978
# 19099      1  1101072  227.7167
# ...      ...      ...       ...
# 95455      4  1125071  881.9419
# 95456      4  1125071  218.0692
# 95457      4  1125071  909.5007
# 95458      4  1125071   15.3889
# 95459      4  1125071  612.1995
#
# [76365 rows x 3 columns]>

# %%
real_pop= new_pop.groupby('집계구코드')['총생활인구수'].mean().reset_index()

# %%
real_pop.head(3)
# Out:
#      집계구코드      총생활인구수
# 0  1101053  646.165247
# 1  1101054  819.472895
# 2  1101055  622.595385

# %%
dong =gpd.read_file('./data/통계지역경계/행정구역.shp', encoding='cp949')

# %%
dong
# Out:
#     SIDO_CD SIDO_NM SIGUNGU_CD SIGUNGU_NM   ADM_CD ADM_NM  \
# 0        11   서울특별시      11010        종로구  1101053    사직동
# 1        11   서울특별시      11010        종로구  1101054    삼청동
# 2        11   서울특별시      11010        종로구  1101055    부암동
# 3        11   서울특별시      11010        종로구  1101056    평창동
# 4        11   서울특별시      11010        종로구  1101057    무악동
# ..      ...     ...        ...        ...      ...    ...
# 419      11   서울특별시      11250        강동구  1125070   둔촌1동
# 420      11   서울특별시      11250        강동구  1125071   둔촌2동
# 421      11   서울특별시      11250        강동구  1125072   암사1동
# 422      11   서울특별시      11250        강동구  1125073   천호2동
# 423      11   서울특별시      11250        강동구  1125074     길동
#
#                                               geometry
# 0    POLYGON ((953553.932 1953335.741, 953555.211 1...
# 1    POLYGON ((953844.081 1955492.177, 953858.644 1...
# 2    POLYGON ((952560.239 1956394.672, 952554.005 1...
# 3    POLYGON ((953683.828 1959209.872, 953647.333 1...
# 4    POLYGON ((952386.354 1952848.711, 952381.494 1...
# ..                                                 ...
# 419  POLYGON ((968611.972 1946736.729, 968614.219 1...
# 420  POLYGON ((969671.909 1948750.666, 969656.712 1...
# 421  POLYGON ((967780.213 1950660.439, 967821.733 1...
# 422  POLYGON ((966110.271 1950148.101, 966118.161 1...
# 423  POLYGON ((968949.403 1949663.221, 968943.832 1...
#
# [424 rows x 7 columns]

# %%
dong.dtypes
# Out:
# SIDO_CD         object
# SIDO_NM         object
# SIGUNGU_CD      object
# SIGUNGU_NM      object
# ADM_CD          object
# ADM_NM          object
# geometry      geometry
# dtype: object

# %%
real_pop.dtypes
# Out:
# 집계구코드      object
# 총생활인구수    float64
# dtype: object

# %%
real_pop = real_pop.rename(columns={'집계구코드':'ADM_CD'})

# %%
dongs = dong.merge(real_pop, on='ADM_CD', how='left')

# %%
dongs.head(2)
# Out:
#   SIDO_CD SIDO_NM SIGUNGU_CD SIGUNGU_NM   ADM_CD ADM_NM  \
# 0      11   서울특별시      11010        종로구  1101053    사직동
# 1      11   서울특별시      11010        종로구  1101054    삼청동
#
#                                             geometry      총생활인구수
# 0  POLYGON ((953553.932 1953335.741, 953555.211 1...  646.165247
# 1  POLYGON ((953844.081 1955492.177, 953858.644 1...  819.472895

# %%
print(dongs.crs)
# Out:
# None

# %%
dongs = dongs.set_crs("epsg:5179")

# %%
print(dongs.crs)
# Out:
# epsg:5179

# %%
plt.rcParams['font.family'] = 'AppleGothic'
# 구 단위로 dissolve
# dissolve 전에 geometry 오류 정리
dongs['geometry'] = dongs['geometry'].buffer(0)
# dissolve
boroughs = dongs.dissolve(by='SIGUNGU_NM')
# dissolve 결과 geometry 오류 정리
boroughs['geometry'] = boroughs['geometry'].buffer(0.001)


fig, ax = plt.subplots(figsize=(15, 10))
dongs.plot(
    column='총생활인구수',
    ax=ax,
    legend=True,
    cmap='OrRd',
    scheme='natural_breaks',
    k=7)
dongs.boundary.plot(
    ax=ax,
    linestyle='dotted',
    lw=0.2,
    color='black',
    zorder=1
)
# # Your code here
# # 구 경계 진하게 추가
boroughs.boundary.plot(
    ax=ax,
    color='black',     # 원하는 색상(예: 'black', 'red', 'blue' 등)
    linestyle='-',
    lw=1,    # 경계선 두께(예: 2~4)
    zorder=2
)


for idx, row in boroughs.iterrows():
    ax.text(s=idx, # String to be displayed
                x=row['geometry'].centroid.coords[:][0][0], # X coordinate of label
                y=row['geometry'].centroid.coords[:][0][1], # Y coordinate of label
                fontsize=12, 
                color='white',
                path_effects=[pe.withStroke(linewidth=1, foreground="black")],
                ha='center', # Horizontal align
                va='center', # Vertical align
               )
ax.set_title(f'거주인구수', fontsize=15)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# %%
boroughs_1 = boroughs.copy()
boroughs_1 = boroughs_1.to_crs(epsg=5179)
boroughs_1['geometry'] = boroughs_1['geometry'].buffer(0.001)
boroughs_1 = boroughs_1.to_crs(epsg=4326)

# %%
parks = parks.to_crs("epsg:4326")
dongs = dongs.to_crs("epsg:4326")
dongs_list = ['Seoul, South Korea']

# 2. UTM-K 좌표계로 임시 변환 (격자 생성용)
from pyproj import CRS
utm_zone = 52  # 서울 기준
parks_utm = parks.to_crs(CRS(f"EPSG:326{utm_zone}"))


G = ox.graph_from_place(dongs_list, network_type='walk')
G.remove_nodes_from(list(nx.isolates(G)))

# %%
supply = gpd.read_file('./supply_data.gpkg')

# %%
supply
# Out:
#        U2_COD U2_NAM        Area   nearest_osm  \
# 0         110    도시숲   27.916095  7.168391e+09
# 1         110    도시숲  427.471653  7.168391e+09
# 2         110    도시숲  807.625803  7.168391e+09
# 3         110    도시숲  246.678781  7.168391e+09
# 4         110    도시숲   80.680325  7.168391e+09
# ...       ...    ...         ...           ...
# 155038    310    가로수  196.667732  9.122097e+09
# 155039    310    가로수   13.766157  1.023761e+10
# 155040    310    가로수   25.741987  1.023761e+10
# 155041    310    가로수  243.289499  8.823892e+09
# 155042    310    가로수  254.460229  8.823892e+09
#
#                                                  geometry
# 0       POLYGON ((127.07118 37.43062, 127.07112 37.430...
# 1       POLYGON ((127.07047 37.43073, 127.07066 37.430...
# 2       POLYGON ((127.07086 37.43108, 127.07086 37.431...
# 3       POLYGON ((127.07035 37.431, 127.07033 37.431, ...
# 4       POLYGON ((127.07016 37.43095, 127.07015 37.430...
# ...                                                   ...
# 155038  POLYGON ((127.04928 37.69094, 127.04926 37.690...
# 155039  POLYGON ((127.04494 37.69224, 127.04492 37.692...
# 155040  POLYGON ((127.04528 37.69225, 127.04526 37.692...
# 155041  POLYGON ((127.04842 37.69235, 127.0484 37.6923...
# 155042  POLYGON ((127.04863 37.6925, 127.0486 37.6925,...
#
# [155043 rows x 5 columns]

# %%
assert parks.crs == G.graph['crs'], "좌표계 불일치"

# %%
demand= utils.nearest_osm(G, dongs)
# Out:
# 100%|█████████████████████████████████████████| 424/424 [01:00<00:00,  6.98it/s]

# %%
supply
# Out:
#       U2_COD U2_NAM        Area                    geometry    nearest_osm  \
# 0        110    도시숲   27.916095  POINT (127.07116 37.43063)   [7168390824]
# 1        110    도시숲  427.471653  POINT (127.07038 37.43065)   [7168390824]
# 2        110    도시숲  807.625803   POINT (127.07073 37.4309)   [7168390824]
# 3        110    도시숲  246.678781  POINT (127.07029 37.43108)   [7168390824]
# 4        110    도시숲   80.680325  POINT (127.06995 37.43105)   [7168390824]
# ...      ...    ...         ...                         ...            ...
# 20295    310    가로수  196.667732   POINT (127.04901 37.6916)   [9122097163]
# 20296    310    가로수   13.766157  POINT (127.04493 37.69227)  [10237611266]
# 20297    310    가로수   25.741987   POINT (127.04526 37.6923)  [10237611266]
# 20298    310    가로수  243.289499  POINT (127.04823 37.69297)   [8823891955]
# 20299    310    가로수  254.460229  POINT (127.04839 37.69316)   [8823891955]
#
#        parent_id
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 20295     155038
# 20296     155039
# 20297     155040
# 20298     155041
# 20299     155042
#
# [162407 rows x 6 columns]

# %%
nodes, edges = ox.graph_to_gdfs(G, nodes = True, edges = True, node_geometry = True)

# %%
G = utils.network_settings_walk(G)
# Out:
# walk network set done

# %%
nodes, edges = ox.graph_to_gdfs(G, nodes=True, edges=True, node_geometry=True)

# %%
weights = {5:1, 15:0.68, 30:0.22}  # keys: time, values: weight

result_step1 = utils.step1_E2SFCA(weights, supply, 'Area', demand, '총생활인구수', G)
# Out:
# 100%|██████████████████████████████████| 155043/155043 [16:58<00:00, 152.17it/s]

# %%
result_step1
# Out:
#        U2_COD U2_NAM        Area   nearest_osm  \
# 0         110    도시숲   27.916095  7.168391e+09
# 1         110    도시숲  427.471653  7.168391e+09
# 2         110    도시숲  807.625803  7.168391e+09
# 3         110    도시숲  246.678781  7.168391e+09
# 4         110    도시숲   80.680325  7.168391e+09
# ...       ...    ...         ...           ...
# 155038    310    가로수  196.667732  9.122097e+09
# 155039    310    가로수   13.766157  1.023761e+10
# 155040    310    가로수   25.741987  1.023761e+10
# 155041    310    가로수  243.289499  8.823892e+09
# 155042    310    가로수  254.460229  8.823892e+09
#
#                                                  geometry         ratio
# 0       POLYGON ((127.07118 37.43062, 127.07112 37.430...           inf
# 1       POLYGON ((127.07047 37.43073, 127.07066 37.430...           inf
# 2       POLYGON ((127.07086 37.43108, 127.07086 37.431...           inf
# 3       POLYGON ((127.07035 37.431, 127.07033 37.431, ...           inf
# 4       POLYGON ((127.07016 37.43095, 127.07015 37.430...           inf
# ...                                                   ...           ...
# 155038  POLYGON ((127.04928 37.69094, 127.04926 37.690...  2.748691e+05
# 155039  POLYGON ((127.04494 37.69224, 127.04492 37.692...  1.924002e+04
# 155040  POLYGON ((127.04528 37.69225, 127.04526 37.692...  3.597782e+04
# 155041  POLYGON ((127.04842 37.69235, 127.0484 37.6923...  3.400292e+05
# 155042  POLYGON ((127.04863 37.6925, 127.0486 37.6925,...  3.556418e+05
#
# [155043 rows x 6 columns]

# %%
result_step2 = utils.step2_E2SFCA(weights, result_step1, demand, G)
# Out:
# Processing demand points: 100%|███████████████| 424/424 [00:12<00:00, 32.68it/s]

# %%
result_step2
# Out:
#     SIDO_CD SIDO_NM SIGUNGU_CD SIGUNGU_NM   ADM_CD ADM_NM  \
# 0        11   서울특별시      11010        종로구  1101053    사직동
# 1        11   서울특별시      11010        종로구  1101054    삼청동
# 2        11   서울특별시      11010        종로구  1101055    부암동
# 3        11   서울특별시      11010        종로구  1101056    평창동
# 4        11   서울특별시      11010        종로구  1101057    무악동
# ..      ...     ...        ...        ...      ...    ...
# 419      11   서울특별시      11250        강동구  1125070   둔촌1동
# 420      11   서울특별시      11250        강동구  1125071   둔촌2동
# 421      11   서울특별시      11250        강동구  1125072   암사1동
# 422      11   서울특별시      11250        강동구  1125073   천호2동
# 423      11   서울특별시      11250        강동구  1125074     길동
#
#                                               geometry      총생활인구수  \
# 0    POLYGON ((126.97399 37.57823, 126.974 37.57809...  646.165247
# 1    POLYGON ((126.97714 37.59768, 126.9773 37.5976...  819.472895
# 2    POLYGON ((126.96253 37.60575, 126.96246 37.605...  622.595385
# 3    POLYGON ((126.97508 37.63118, 126.97468 37.629...  541.615290
# 4    POLYGON ((126.96079 37.57378, 126.96074 37.573...  389.776531
# ..                                                 ...         ...
# 419  POLYGON ((127.1448 37.51939, 127.14483 37.5192...  838.039244
# 420  POLYGON ((127.15671 37.53758, 127.15654 37.537...  487.941971
# 421  POLYGON ((127.13522 37.55473, 127.13569 37.554...  463.037580
# 422  POLYGON ((127.11633 37.55005, 127.11642 37.550...  696.772748
# 423  POLYGON ((127.1485 37.54578, 127.14843 37.5454...  662.539863
#
#       nearest_osm        access
# 0    2.304578e+09  3.372884e+07
# 1    4.198106e+09  1.523448e+08
# 2    4.368693e+08  1.936660e+08
# 3    2.303508e+09  1.487782e+08
# 4    3.096779e+09  1.169129e+08
# ..            ...           ...
# 419  1.245110e+10  4.782529e+07
# 420  5.273883e+09  7.107733e+07
# 421  4.194375e+09  6.527395e+07
# 422  3.844539e+09  3.811411e+07
# 423  3.856135e+09  6.853841e+07
#
# [424 rows x 10 columns]

# %%
result_step2_nor = result_step2.copy(deep=True)


min_sum = result_step2_nor['access'].min()
max_sum = result_step2_nor['access'].max()
# if 문을 통해 반복을 돌린다. 이를 하지 않았더니 똑같은 값만 나왔었다.
if max_sum == min_sum:
    print('틀렸다')
else:
    result_step2_nor['access_normalized'] = (result_step2_nor['access'] - min_sum) / (max_sum - min_sum)

# %%
result_step2_nor
# Out:
#     SIDO_CD SIDO_NM SIGUNGU_CD SIGUNGU_NM   ADM_CD ADM_NM  \
# 0        11   서울특별시      11010        종로구  1101053    사직동
# 1        11   서울특별시      11010        종로구  1101054    삼청동
# 2        11   서울특별시      11010        종로구  1101055    부암동
# 3        11   서울특별시      11010        종로구  1101056    평창동
# 4        11   서울특별시      11010        종로구  1101057    무악동
# ..      ...     ...        ...        ...      ...    ...
# 419      11   서울특별시      11250        강동구  1125070   둔촌1동
# 420      11   서울특별시      11250        강동구  1125071   둔촌2동
# 421      11   서울특별시      11250        강동구  1125072   암사1동
# 422      11   서울특별시      11250        강동구  1125073   천호2동
# 423      11   서울특별시      11250        강동구  1125074     길동
#
#                                               geometry      총생활인구수  \
# 0    POLYGON ((126.97399 37.57823, 126.974 37.57809...  646.165247
# 1    POLYGON ((126.97714 37.59768, 126.9773 37.5976...  819.472895
# 2    POLYGON ((126.96253 37.60575, 126.96246 37.605...  622.595385
# 3    POLYGON ((126.97508 37.63118, 126.97468 37.629...  541.615290
# 4    POLYGON ((126.96079 37.57378, 126.96074 37.573...  389.776531
# ..                                                 ...         ...
# 419  POLYGON ((127.1448 37.51939, 127.14483 37.5192...  838.039244
# 420  POLYGON ((127.15671 37.53758, 127.15654 37.537...  487.941971
# 421  POLYGON ((127.13522 37.55473, 127.13569 37.554...  463.037580
# 422  POLYGON ((127.11633 37.55005, 127.11642 37.550...  696.772748
# 423  POLYGON ((127.1485 37.54578, 127.14843 37.5454...  662.539863
#
#       nearest_osm        access  access_normalized
# 0    2.304578e+09  3.372884e+07           0.030209
# 1    4.198106e+09  1.523448e+08           0.144091
# 2    4.368693e+08  1.936660e+08           0.183763
# 3    2.303508e+09  1.487782e+08           0.140667
# 4    3.096779e+09  1.169129e+08           0.110073
# ..            ...           ...                ...
# 419  1.245110e+10  4.782529e+07           0.043743
# 420  5.273883e+09  7.107733e+07           0.066067
# 421  4.194375e+09  6.527395e+07           0.060495
# 422  3.844539e+09  3.811411e+07           0.034419
# 423  3.856135e+09  6.853841e+07           0.063629
#
# [424 rows x 11 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 10))

# 구 단위로 dissolve
# dissolve 전에 geometry 오류 정리
result_step2_nor['geometry'] = result_step2_nor['geometry'].buffer(0)
# dissolve
boroughs = result_step2_nor.dissolve(by='SIGUNGU_NM')

boroughs_1 = boroughs.copy()
boroughs_1 = boroughs_1.to_crs(epsg=5179)
boroughs_1['geometry'] = boroughs_1['geometry'].buffer(0.001)
boroughs_1 = boroughs_1.to_crs(epsg=4326)


# 첫 번째 지도: demand_
result_step2_nor.plot(
    column='access_normalized',
    ax=ax,
    legend=True,
    cmap='Blues',
    scheme='naturalbreaks',
    k=7
)
result_step2_nor.boundary.plot(
    ax=ax,
    linestyle='dotted',
    lw=0.5,
    color='black',
    zorder=1
)

boroughs_1.boundary.plot(
    ax=ax,
    color='black',     # 원하는 색상(예: 'black', 'red', 'blue' 등)
    linestyle='-',
    lw=1,    # 경계선 두께(예: 2~4)
    zorder=2
)
for idx, row in boroughs_1.iterrows():
    ax.text(s=idx, # String to be displayed
                x=row['geometry'].centroid.coords[:][0][0], # X coordinate of label
                y=row['geometry'].centroid.coords[:][0][1], # Y coordinate of label
                fontsize=12, 
                color='white',
                path_effects=[pe.withStroke(linewidth=1, foreground="black")],
                ha='center', # Horizontal align
                va='center', # Vertical align
               )
ax.set_title(f'서울시 녹지 면적 접근성 E2SFCA by centroid', fontsize=15)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)


# scalebar = ScaleBar(dx=1, units="m", location='lower right')  # dx=1은 좌표계가 미터 단위일 때
# ax.add_artist(scalebar)

# %%
import matplotlib.pyplot as plt
plt.hist(result_step2_nor['access_normalized'], bins=30)  # 히스토그램으로 분포 확인
plt.show()

# %%
dongs.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SIDO_CD      424 non-null    object
#  1   SIDO_NM      424 non-null    object
#  2   SIGUNGU_CD   424 non-null    object
#  3   SIGUNGU_NM   424 non-null    object
#  4   ADM_CD       424 non-null    object
#  5   ADM_NM       424 non-null    object
#  6   geometry     424 non-null    geometry
#  7   총생활인구수       424 non-null    float64
#  8   nearest_osm  424 non-null    float64
# dtypes: float64(2), geometry(1), object(6)
# memory usage: 29.9+ KB

# %%
dongs['총생활인구수'].describe()
# Out:
# count      424.000000
# mean       619.669536
# std       1624.237038
# min        137.723546
# 25%        407.831778
# 50%        496.043481
# 75%        600.462766
# max      33694.172275
# Name: 총생활인구수, dtype: float64

# %%
max_idx = dongs['총생활인구수'].idxmax()
dongs.loc[max_idx]
# Out:
# SIDO_CD                                                       11
# SIDO_NM                                                    서울특별시
# SIGUNGU_CD                                                 11240
# SIGUNGU_NM                                                   송파구
# ADM_CD                                                   1124066
# ADM_NM                                                      가락1동
# geometry       POLYGON ((127.1101515247529 37.50051059492555,...
# 총생활인구수                                              33694.172275
# nearest_osm                                         2911195456.0
# Name: 394, dtype: object

# %%
min_idx = dongs['총생활인구수'].idxmin()
dongs.loc[min_idx]
# Out:
# SIDO_CD                                                       11
# SIDO_NM                                                    서울특별시
# SIGUNGU_CD                                                 11220
# SIGUNGU_NM                                                   서초구
# ADM_CD                                                   1122056
# ADM_NM                                                      반포본동
# geometry       POLYGON ((126.99222812629364 37.50663133440654...
# 총생활인구수                                                137.723546
# nearest_osm                                        10124068123.0
# Name: 344, dtype: object

# %%
result_step2_nor.to_file("./최종2_그리드_녹지면적접근성분석_도보.shp", driver="ESRI Shapefile")

# %%
result_step2_nor.to_file("./진짜최종_도보_30min_centroid.gpkg", driver="GPKG")

# %%
result_step2_nor.to_csv("./최종2_그리드_녹지면적접근성분석_도보.csv", encoding="utf-8", index=False)

# %%
print(type(supply))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
supply.to_file(
    "supply_data.gpkg", 
    driver="GPKG",
    layer="parks_supply",  # 레이어 이름 지정
    encoding="utf-8"
)

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from esda.moran import Moran, Moran_Local
from splot.esda import moran_scatterplot, plot_moran, lisa_cluster
from scipy.stats import ks_2samp
import esda
import libpysal
# 1. 데이터 준비 (가정)
grid_access = gpd.read_file('최종2_그리드_녹지면적접근성분석_도보.gpkg')  # 그리드 기반 결과
centroid_access = gpd.read_file('녹지면적접근성분석_도보.gpkg')  # 중심점 기반 결과

# 2. 공간 가중치 생성 (퀸 contiguity 기준)

w = libpysal.weights.Queen.from_dataframe(grid_access, use_index=True)  # 그리드 결과 기준 가중치
w.transform = 'r'  # 행 표준화

# 3. Global Moran's I 계산
def calculate_moran(access_data, w):
    moran = Moran(access_data['access'].values, w)
    print(f"Moran's I: {moran.I:.3f}")
    print(f"P-value: {moran.p_sim:.5f}")
    
    # Moran 플롯
    fig, ax = moran_scatterplot(moran, aspect_equal=True)
    plt.show()
    return moran

print("그리드 기반 Moran's I:")
moran_grid = calculate_moran(grid_access, w)

print("\n중심점 기반 Moran's I:")
moran_centroid = calculate_moran(centroid_access, w)

# 4. LISA 분석
def calculate_lisa(access_data, w):
    moran_loc = Moran_Local(access_data['access'].values, w)
    
    # LISA 클러스터 맵
    fig, ax = lisa_cluster(moran_loc, access_data)
    plt.show()
    return moran_loc

print("\n그리드 기반 LISA 분석:")
lisa_grid = calculate_lisa(grid_access, w)

print("\n중심점 기반 LISA 분석:")
lisa_centroid = calculate_lisa(centroid_access, w)

# 5. Gini 계수 계산 (검색결과[3] 참조)
def gini(array):
    array = array.flatten()
    array += 1e-10  # 0 값 방지
    array = np.sort(array)
    n = len(array)
    index = np.arange(1, n+1)
    return (np.sum((2 * index - n - 1) * array)) / (n * np.sum(array))

gini_grid = gini(grid_access['access'].values)
gini_centroid = gini(centroid_access['access'].values)
print(f"\nGini 계수 - 그리드: {gini_grid:.3f}, 중심점: {gini_centroid:.3f}")

# 6. Kolmogorov-Smirnov 검정
ks_stat, ks_p = ks_2samp(grid_access['access'], centroid_access['access'])
print(f"\nKS 검정 결과: 통계량={ks_stat:.3f}, p-value={ks_p:.5f}")

# 7. 결과 시각화
fig, ax = plt.subplots(1,2, figsize=(15,6))

# Moran's I 비교
ax[0].bar(['Grid', 'Centroid'], 
          [moran_grid.I, moran_centroid.I],
          color=['blue', 'orange'])
ax[0].set_title("Global Moran's I 비교")

# Gini 계수 비교
ax[1].bar(['Grid', 'Centroid'],
          [gini_grid, gini_centroid],
          color=['blue', 'orange'])
ax[1].set_title("Gini 계수 비교")

plt.show()
# Out:
# ('WARNING: ', 5, ' is an island (no neighbors)')
# ('WARNING: ', 30, ' is an island (no neighbors)')
# ('WARNING: ', 37, ' is an island (no neighbors)')
# ('WARNING: ', 66, ' is an island (no neighbors)')
# ('WARNING: ', 75, ' is an island (no neighbors)')
# ('WARNING: ', 117, ' is an island (no neighbors)')
# ('WARNING: ', 187, ' is an island (no neighbors)')
# ('WARNING: ', 197, ' is an island (no neighbors)')
# ('WARNING: ', 215, ' is an island (no neighbors)')
# ('WARNING: ', 270, ' is an island (no neighbors)')
# ('WARNING: ', 271, ' is an island (no neighbors)')
# ('WARNING: ', 282, ' is an island (no neighbors)')
# ('WARNING: ', 312, ' is an island (no neighbors)')
# ('WARNING: ', 317, ' is an island (no neighbors)')
# ('WARNING: ', 319, ' is an island (no neighbors)')
# ('WARNING: ', 355, ' is an island (no neighbors)')
# ('WARNING: ', 382, ' is an island (no neighbors)')
# ('WARNING: ', 383, ' is an island (no neighbors)')
# ('WARNING: ', 405, ' is an island (no neighbors)')
# ('WARNING: ', 407, ' is an island (no neighbors)')
# 그리드 기반 Moran's I:
# Moran's I: 0.246
# P-value: 0.00100
# 중심점 기반 Moran's I:
# Moran's I: 0.069
# P-value: 0.01500
# 그리드 기반 LISA 분석:
# 중심점 기반 LISA 분석:
# Gini 계수 - 그리드: 0.475, 중심점: 0.513
#
# KS 검정 결과: 통계량=0.517, p-value=0.00000

# %%
# !pip install splot
# Out:
# Collecting splot
#   Downloading splot-1.1.7-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: esda in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from splot) (2.7.0)
# Requirement already satisfied: geopandas>=0.9.0 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from splot) (1.0.1)
# Collecting giddy (from splot)
#   Downloading giddy-2.3.6-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: libpysal in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from splot) (4.13.0)
# Requirement already satisfied: mapclassify in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from splot) (2.8.1)
# Requirement already satisfied: matplotlib>=3.3.3 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from splot) (3.10.1)
# Requirement already satisfied: numpy in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from splot) (2.2.5)
# Requirement already satisfied: packaging in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from splot) (25.0)
# Collecting seaborn>=0.11.0 (from splot)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting spreg (from splot)
#   Downloading spreg-1.8.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from geopandas>=0.9.0->splot) (0.11.0)
# Requirement already satisfied: pandas>=1.4.0 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from geopandas>=0.9.0->splot) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from geopandas>=0.9.0->splot) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from geopandas>=0.9.0->splot) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from pandas>=1.4.0->geopandas>=0.9.0->splot) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from pandas>=1.4.0->geopandas>=0.9.0->splot) (2025.2)
# Requirement already satisfied: certifi in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas>=0.9.0->splot) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->splot) (1.17.0)
# Requirement already satisfied: scikit-learn>=1.2 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from esda->splot) (1.6.1)
# Requirement already satisfied: scipy>=1.9 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from esda->splot) (1.15.2)
# Requirement already satisfied: beautifulsoup4>=4.10 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from libpysal->splot) (4.13.4)
# Requirement already satisfied: platformdirs>=2.0.2 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from libpysal->splot) (4.3.8)
# Requirement already satisfied: requests>=2.27 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from libpysal->splot) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from beautifulsoup4>=4.10->libpysal->splot) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from beautifulsoup4>=4.10->libpysal->splot) (4.13.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from requests>=2.27->libpysal->splot) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from requests>=2.27->libpysal->splot) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from requests>=2.27->libpysal->splot) (2.4.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from scikit-learn>=1.2->esda->splot) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from scikit-learn>=1.2->esda->splot) (3.6.0)
# Collecting quantecon>=0.7 (from giddy->splot)
#   Downloading quantecon-0.8.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: networkx>=2.7 in /opt/miniconda3/envs/GIS_Project/lib/python3.13/site-packages (from mapclassify->splot) (3.4.2)
# Collecting numba>=0.49.0 (from quantecon>=0.7->giddy->splot)
#   Downloading numba-0.61.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting sympy (from quantecon>=0.7->giddy->splot)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.49.0->quantecon>=0.7->giddy->splot)
#   Downloading llvmlite-0.44.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->quantecon>=0.7->giddy->splot)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading splot-1.1.7-py3-none-any.whl (39 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading giddy-2.3.6-py3-none-any.whl (61 kB)
# Downloading quantecon-0.8.0-py3-none-any.whl (322 kB)
# Downloading numba-0.61.2-cp313-cp313-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 11.3 MB/s eta 0:00:00a 0:00:01
# Downloading llvmlite-0.44.0-cp313-cp313-macosx_11_0_arm64.whl (26.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/26.2 MB 11.3 MB/s eta 0:00:00a 0:00:01
# Downloading spreg-1.8.3-py3-none-any.whl (389 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 11.6 MB/s eta 0:00:00a 0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 8.3 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, llvmlite, numba, seaborn, quantecon, spreg, giddy, splot
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [splot]32m6/9 [spreg]n]]
# Successfully installed giddy-2.3.6 llvmlite-0.44.0 mpmath-1.3.0 numba-0.61.2 quantecon-0.8.0 seaborn-0.13.2 splot-1.1.7 spreg-1.8.3 sympy-1.14.0
